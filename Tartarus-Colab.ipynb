# %%
# !pip install -q condacolab
import condacolab
condacolab.install() # expect a kernel restart
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:17
# 🔁 Restarting kernel...

# %%
# !mamba install openbabel rdkit -c conda-forge -y
# !pip install git+https://github.com/Xiangyan93/Tartarus.git@dev
# Out:
# Looking for: ['openbabel', 'rdkit']
#
# [+] 0.0s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.3s
# conda-forge/linux-64   1%
# conda-forge/noarch     2%[+] 0.4s
# conda-forge/linux-64   2%
# conda-forge/noarch     4%[+] 0.5s
# conda-forge/linux-64   5%
# conda-forge/noarch     6%[+] 0.6s
# conda-forge/linux-64   7%
# conda-forge/noarch    13%[+] 0.7s
# conda-forge/linux-64   9%
# conda-forge/noarch    22%[+] 0.8s
# conda-forge/linux-64  14%
# conda-forge/noarch    31%[+] 0.9s
# conda-forge/linux-64  18%
# conda-forge/noarch    35%[+] 1.0s
# conda-forge/linux-64  21%
# conda-forge/noarch    41%[+] 1.1s
# conda-forge/linux-64  22%
# conda-forge/noarch    48%[+] 1.2s
# conda-forge/linux-64  24%
# conda-forge/noarch    50%[+] 1.3s
# conda-forge/linux-64  27%
# conda-forge/noarch    56%[+] 1.4s
# conda-forge/linux-64  29%
# ...

# %%
from tartarus import docking
smiles = "O=C1c2ccccc2CN(C(=O)Nc2ccccc2)c2ccccc21"
protein = "6y2f"
scores = [docking.perform_calc_single(smiles, protein, docking_program='qvina', bin='', save_pdb=True) for i in range(5)]

# %%
scores
# Out:
# [-7.3, -7.3, -7.2, -7.3, -7.3]
